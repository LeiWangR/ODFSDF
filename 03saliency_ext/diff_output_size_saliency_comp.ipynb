# %% [markdown]
# # Effects of different size of output for saliency maps generation
#
# Lei Wang
#
# 10 Sep. 2019

# %%
sample = 'ACL/video_data/SkateBoarding-Front-006'

# %% [markdown]
# ## Section 1: video frame images

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import glob
import cv2

plt.figure(figsize=(15,30))
filelist = glob.glob(sample + '/images/*.png')
# print(filelist)
for i, file in zip(range(len(filelist)), sorted(filelist)):
    # print(file)
    plt.subplot(18, 4, i+1)
    im = cv2.imread(file)
    plt.imshow(im)
    plt.xticks([])
    plt.yticks([])
    plt.title('Frame No. {}'.format(i+1))

# %% [markdown]
# ## Section 2: ground truth saliency maps

# %%
plt.figure(figsize=(15,30))
filelist = glob.glob(sample + '/maps/*.png')
# print(filelist)
for i, file in zip(range(len(filelist)), sorted(filelist)):
    # print(file)
    plt.subplot(18, 4, i+1)
    im = cv2.imread(file)
    plt.imshow(im)
    plt.xticks([])
    plt.yticks([])
    plt.title('Frame No. {}'.format(i+1))

# %% [markdown]
# ## Section 3: predicted saliency maps

# %%
plt.figure(figsize=(15,30))
filelist = glob.glob(sample + '/saliency/*.png')
# print(filelist)
for i, file in zip(range(len(filelist)), sorted(filelist)):
    # print(file)
    plt.subplot(18, 4, i+1)
    im = cv2.imread(file)
    plt.imshow(im)
    plt.xticks([])
    plt.yticks([])
    plt.title('Frame No. {}'.format(i+1))

# %% [markdown]
# ## The END

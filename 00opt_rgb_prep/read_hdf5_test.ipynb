# %% [markdown]
# # Section 1: For hdf5 created from videos (e.g., Moments in Time dataset)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import h5py
import cv2

videoname = 'writing/Z3CYTr-mXWk_35'
# videoname = 'diving/yt-iSaJlFbFgdg_272'

filename = 'sample.hdf5'
f = h5py.File(filename, 'r')

# using [()] for value
count = f['rgb/' + videoname + '/count'][()]
fps = f['rgb/' + videoname + '/fps'][()]


print('count: ', count, ' | fps: ', fps)

for ii in range(count):
    # using [:] for image stream
    frame = f['rgb/' + videoname + '/frame' + str(ii).zfill(8)][:]
    # print(frame.shape)
    im = cv2.imdecode(frame, cv2.IMREAD_COLOR)
    # print(im.shape)
    # print('--------')
    # print(im)
    
    imgplot = plt.imshow(im)
f.close()
# Out:
# count:  75  | fps:  25.0

# %%
filename = 'sample.hdf5'
f = h5py.File(filename, 'r')
count = f['u/' + videoname + '/count'][()]
for ii in range(count):
    frame = f['u/' + videoname + '/frame' + str(ii).zfill(8)][:]
    # print(frame.shape)
    im = cv2.imdecode(frame, cv2.IMREAD_GRAYSCALE)
    # print(im.shape)
    # print('--------')
    # print(im)
    
    imgplot = plt.imshow(im)
f.close()

# %%
filename = 'sample.hdf5'
f = h5py.File(filename, 'r')
for ii in range(count):
    frame = f['v/' + videoname + '/frame' + str(ii).zfill(8)][:]
    # print(frame.shape)
    im = cv2.imdecode(frame, cv2.IMREAD_GRAYSCALE)
    # print(im.shape)
    # print('--------')
    # print(im)
    
    imgplot = plt.imshow(im)
f.close()

# %% [markdown]
# # Section 2: For hdf5 created from video frame images (e.g., MPII Cooking dataset)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import h5py
import cv2

videoname = 's20-d07-cam-002_05493_034'
# videoname = 'diving/yt-iSaJlFbFgdg_272'

filename = 'mpii_sample.hdf5'
f = h5py.File(filename, 'r')

# using [()] for value
count = f['rgb/' + videoname + '/count'][()]
height = f['rgb/' + videoname + '/height'][()]
width = f['rgb/' + videoname + '/width'][()]

print('count: ', count, ' | height: ', height, ' | width: ', width)

for ii in range(count):
    # using [:] for image stream
    frame = f['rgb/' + videoname + '/frame' + str(ii).zfill(8)][:]
    # print(frame.shape)
    im = cv2.imdecode(frame, cv2.IMREAD_COLOR)
    # print(im.shape)
    # print('--------')
    # print(im)
    
    imgplot = plt.imshow(im)
f.close()
# Out:
# count:  110  | height:  512  | width:  680

# %%
filename = 'mpii_sample.hdf5'
f = h5py.File(filename, 'r')

# using [()] for value
count = f['u/' + videoname + '/count'][()]
height = f['u/' + videoname + '/height'][()]
width = f['u/' + videoname + '/width'][()]

print('count: ', count, ' | height: ', height, ' | width: ', width)

for ii in range(count):
    # using [:] for image stream
    frame = f['u/' + videoname + '/frame' + str(ii + 1).zfill(8)][:]
    # print(frame.shape)
    im = cv2.imdecode(frame, cv2.IMREAD_GRAYSCALE)
    # print(im.shape)
    # print('--------')
    # print(im)
    
    imgplot = plt.imshow(im)
f.close()
# Out:
# count:  109  | height:  512  | width:  680

# %%
filename = 'mpii_sample.hdf5'
f = h5py.File(filename, 'r')

for ii in range(count):
    # using [:] for image stream
    frame = f['v/' + videoname + '/frame' + str(ii + 1).zfill(8)][:]
    # print(frame.shape)
    im = cv2.imdecode(frame, cv2.IMREAD_GRAYSCALE)
    # print(im.shape)
    # print('--------')
    # print(im)
    
    imgplot = plt.imshow(im)
f.close()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import h5py
import cv2

videoname = 's20-d07-cam-002_05493_034'
# videoname = 'diving/yt-iSaJlFbFgdg_272'

filename = 'mpii_sample_bb.hdf5'
f = h5py.File(filename, 'r')

# using [()] for value
count = f['rgb/' + videoname + '/count'][()]

print('count: ', count)

for ii in range(count):
    # using [:] for image stream
    frame = f['rgb/' + videoname + '/frame' + str(ii).zfill(8)][:]
    # print(frame.shape)
    im = cv2.imdecode(frame, cv2.IMREAD_COLOR)
    # print(im.shape)
    # print('--------')
    # print(im)
    
    imgplot = plt.imshow(im)
f.close()
# Out:
# count:  110

# %%
filename = 'mpii_sample_bb.hdf5'
f = h5py.File(filename, 'r')

# using [()] for value
count = f['u/' + videoname + '/count'][()]

print('count: ', count)

for ii in range(count):
    # using [:] for image stream
    frame = f['u/' + videoname + '/frame' + str(ii + 1).zfill(8)][:]
    # print(frame.shape)
    im = cv2.imdecode(frame, cv2.IMREAD_GRAYSCALE)
    # print(im.shape)
    # print('--------')
    # print(im)
    
    imgplot = plt.imshow(im)
f.close()
# Out:
# count:  109

# %%
filename = 'mpii_sample_bb.hdf5'
f = h5py.File(filename, 'r')

for ii in range(count):
    # using [:] for image stream
    frame = f['v/' + videoname + '/frame' + str(ii + 1).zfill(8)][:]
    # print(frame.shape)
    im = cv2.imdecode(frame, cv2.IMREAD_GRAYSCALE)
    # print(im.shape)
    # print('--------')
    # print(im)
    
    imgplot = plt.imshow(im)
f.close()
